# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Practice project on Medical Cost Insurance

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/medical_cost_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(25)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df.tail(25)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1315   18    male  28.310         1     no  northeast  11272.33139
# 1316   19  female  20.600         0     no  southwest   1731.67700
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1318   35    male  39.710         4     no  northeast  19496.71917
# 1319   39  female  26.315         2     no  northwest   7201.70085
# 1320   31    male  31.065         3     no  northwest   5425.02335
# 1321   62    male  26.695         0    yes  northeast  28101.33305
# 1322   62    male  38.830         0     no  southeast  12981.34570
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1324   31    male  25.935         1     no  northwest   4239.89265
# 1325   61    male  33.535         0     no  northeast  13143.33665
# ...

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.nunique().to_frame("No. of unique values")
# Out:
#           No. of unique values
# age                         47
# sex                          2
# bmi                        548
# children                     6
# smoker                       2
# region                       4
# charges                   1337

# %%
df["charges"].value_counts()
# Out:
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.countplot(x=df["sex"], palette="cool")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x=df["smoker"], palette="cool")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x=df["region"], palette="cool")
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
sns.countplot(x=df["children"], palette="cool")
print(df["children"].value_counts())
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
plt.title("comparison between sex and charges")
sns.stripplot(x="sex", y="charges", data=df)
plt.show()

# %%
plt.title("comparison between smoker and charges")
sns.stripplot(x="smoker", y="charges", data=df)
plt.show()

# %%
plt.title("comparison between region and charges")
sns.stripplot(x="region", y="charges", data=df)
plt.show()

# %%
plt.title("comparison between age and charges")
sns.scatterplot(x="age", y="charges", data=df, hue="smoker", palette="bright")
plt.show()

# %%
plt.title("comparison between bmi and charges")
sns.scatterplot(x="bmi", y="charges", data=df, hue="smoker", palette="bright")
plt.show()

# %%
plt.title("comparison between region and charges")
sns.scatterplot(x="region", y="charges", data=df, hue="smoker", palette="bright")
plt.show()

# %%
plt.title("comparison between sex and charges")
sns.barplot(x="sex", y="charges", data=df, hue="smoker", palette="winter_r")
plt.show()

# %%
plt.title("comparison between region and charges")
sns.barplot(x="region", y="charges", data=df, hue="smoker", palette="winter_r")
plt.show()

# %%
sns.catplot(x="smoker", col="sex", data=df, kind="count", palette="spring_r")

# %%
sns.catplot(x="smoker", col="region", data=df, kind="count", palette="spring_r")

# %%
sns.pairplot(df, hue="smoker",  palette="Dark2")
plt.show()

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
    print("Categorical Columns:",categorical_col)
    print("\n")
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
    print("Numerical Columns:",numerical_col)
    print("\n")
# Out:
# Categorical Columns: []
#
#
# Categorical Columns: ['sex']
#
#
# Categorical Columns: ['sex']
#
#
# Categorical Columns: ['sex']
#
#
# Categorical Columns: ['sex', 'smoker']
#
#
# Categorical Columns: ['sex', 'smoker', 'region']
#
#
# Categorical Columns: ['sex', 'smoker', 'region']
#
#
# Numerical Columns: ['age']
#
#
# Numerical Columns: ['age']
#
#
# Numerical Columns: ['age', 'bmi']
#
#
# Numerical Columns: ['age', 'bmi', 'children']
#
#
# Numerical Columns: ['age', 'bmi', 'children']
#
#
# Numerical Columns: ['age', 'bmi', 'children']
#
#
# Numerical Columns: ['age', 'bmi', 'children', 'charges']

# %% [markdown]
# Checking For Outliers (we do not detect/remove outliers from categorical and target variable)

# %%
plt.figure(figsize=(10,6), facecolor="white")
plotnumber=1
for col in numerical_col:
    if plotnumber<=4:
        ax=plt.subplot(2,2, plotnumber)
        sns.boxplot(df[col], palette="Set2_r")
        plt.xlabel(col, fontsize=15)
        plt.yticks(rotation=0, fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# checking for skewness (acceptable range -0.5 to 0.5)

# %%
df.skew()
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64

# %%
sns.distplot(df["bmi"], color="r", kde_kws={"shade":True}, hist=False)
plt.show()

# %%
sns.distplot(df["age"], color="r", kde_kws={"shade":True}, hist=False)
plt.show()

# %% [markdown]
# we do not remove skewness and outliers from target/dependent variable and categorical column
# we don apply scaling method on target variable

# %% [markdown]
# to remove the outliers we can use IQR or z-score method

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region    charges
# 0      19  0.0  27.900   0.00000     1.0     3.0  25.654666
# 1      18  1.0  33.770   1.00000     0.0     2.0  11.994331
# 2      28  1.0  33.000   1.44225     0.0     2.0  16.447599
# 3      33  1.0  22.705   0.00000     0.0     1.0  28.013799
# 4      32  1.0  28.880   0.00000     0.0     1.0  15.695891
# ...   ...  ...     ...       ...     ...     ...        ...
# 1333   50  1.0  30.970   1.44225     0.0     1.0  21.967271
# 1334   18  0.0  31.920   0.00000     0.0     0.0  13.017690
# 1335   18  0.0  36.850   0.00000     0.0     2.0  11.768318
# 1336   21  0.0  25.800   0.00000     0.0     3.0  12.615872
# 1337   61  0.0  29.070   0.00000     1.0     1.0  30.773007
#
# [1338 rows x 7 columns]

# %%
df.head(50)
# Out:
#     age  sex     bmi  children  smoker  region    charges
# 0    19  0.0  27.900  0.000000     1.0     3.0  25.654666
# 1    18  1.0  33.770  1.000000     0.0     2.0  11.994331
# 2    28  1.0  33.000  1.442250     0.0     2.0  16.447599
# 3    33  1.0  22.705  0.000000     0.0     1.0  28.013799
# 4    32  1.0  28.880  0.000000     0.0     1.0  15.695891
# 5    31  0.0  25.740  0.000000     0.0     2.0  15.545302
# 6    46  0.0  33.440  1.000000     0.0     2.0  20.198514
# 7    37  0.0  27.740  1.442250     0.0     1.0  19.382378
# 8    37  1.0  29.830  1.259921     0.0     0.0  18.572552
# 9    60  0.0  25.840  0.000000     0.0     1.0  30.696001
# 10   25  1.0  26.220  0.000000     0.0     0.0  13.961323
# 11   62  0.0  26.290  0.000000     1.0     2.0  30.296586
# 12   23  1.0  34.400  0.000000     0.0     3.0  12.224574
# 13   56  0.0  39.820  0.000000     0.0     2.0  22.300771
# 14   27  1.0  42.130  0.000000     1.0     2.0  34.088512
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   float64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   float64
#  4   smoker    1338 non-null   float64
#  5   region    1338 non-null   float64
#  6   charges   1338 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 73.3 KB

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     0.690044     0.204783
# std      14.049960     0.500160     6.098187     0.617662     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     1.259921     0.000000
# max      64.000000     1.000000    53.130000     1.709976     1.000000
#
#             region      charges
# count  1338.000000  1338.000000
# mean      1.515695    21.740315
# std       1.104885     6.609017
# min       0.000000    10.390777
# 25%       1.000000    16.798411
# 50%       2.000000    21.091088
# 75%       2.000000    25.529963
# max       3.000000    39.952115

# %%
cor=df.corr()
cor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.048919 -0.025019  0.002127  0.451354
# sex      -0.020856  1.000000  0.046371  0.016183  0.076185  0.004588  0.027560
# bmi       0.109272  0.046371  1.000000  0.016515  0.003750  0.157566  0.156375
# children  0.048919  0.016183  0.016515  1.000000  0.011829  0.014133  0.128511
# smoker   -0.025019  0.076185  0.003750  0.011829  1.000000 -0.002181  0.732564
# region    0.002127  0.004588  0.157566  0.014133 -0.002181  1.000000 -0.029807
# charges   0.451354  0.027560  0.156375  0.128511  0.732564 -0.029807  1.000000

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), linewidths=0.1, fmt=".1g", linecolor="black", annot=True, cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
cor["charges"].sort_values(ascending=False)
# Out:
# charges     1.000000
# smoker      0.732564
# age         0.451354
# bmi         0.156375
# children    0.128511
# sex         0.027560
# region     -0.029807
# Name: charges, dtype: float64

# %%
plt.figure(figsize=(22,7))
df.corr()["charges"].sort_values(ascending=False).drop(["charges"]).plot(kind="bar", color="m")
plt.xlabel("Feature", fontsize=15);
plt.ylabel("Target", fontsize=15);
plt.title("correlation between features and target using barplot", fontsize=20)
plt.show()

# %%
x=df.drop("charges", axis=1)
y=df["charges"]

# %% [markdown]
# Standarization of a dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.438764 -1.010519 -0.453320 -1.117604  1.970587  1.343905
# 1    -1.509965  0.989591  0.509621  0.502009 -0.507463  0.438495
# 2    -0.797954  0.989591  0.383307  1.218282 -0.507463  0.438495
# 3    -0.441948  0.989591 -1.305531 -1.117604 -0.507463 -0.466915
# 4    -0.513149  0.989591 -0.292556 -1.117604 -0.507463 -0.466915
# ...        ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.218282 -0.507463 -0.466915
# 1334 -1.509965 -1.010519  0.206139 -1.117604 -0.507463 -1.372326
# 1335 -1.509965 -1.010519  1.014878 -1.117604 -0.507463  0.438495
# 1336 -1.296362 -1.010519 -0.797813 -1.117604 -0.507463  1.343905
# 1337  1.551686 -1.010519 -0.261388 -1.117604  1.970587 -0.466915
#
# [1338 rows x 6 columns]

# %% [markdown]
# To remove the multicolinearity using variance inflation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values, i) 
                  for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#    VIF values  Features
# 0    1.015956       age
# 1    1.008844       sex
# 2    1.040656       bmi
# 3    1.003101  children
# 4    1.006551    smoker
# 5    1.025881    region

# %%
y.value_counts()
# Out:
# 11.791690    2
# 25.654666    1
# 30.839610    1
# 13.048271    1
# 27.052506    1
#             ..
# 19.438627    1
# 29.666427    1
# 30.469610    1
# 10.475061    1
# 30.773007    1
# Name: charges, Length: 1337, dtype: int64

# %% [markdown]
# MODEL DEVELOPMENT

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("maximum r2 score is", maxAccu, "at random state", maxRS)
# Out:
# maximum r2 score is 0.84511333981896 at random state 13

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=maxRS)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso, Ridge

# %%
LR=LinearRegression()
LR.fit(x_train, y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2_score", r2_score(y_test,pred_LR))
print("R2_score on training Data:", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score 0.805924597234581
# R2_score on training Data: 76.74030799765293
# Mean Absolute Error: 1.9544128516387682
# Mean Squared Error: 8.494884453337123
# Root Mean Squared Error: 2.9145985063704956

# %%
plt.figure(figsize=(10,7))
plt.scatter(x=pred_LR,y=y_test, color="r")
plt.plot(pred_LR, pred_LR, color="b")
plt.xlabel("Actual", fontsize=14)
plt.ylabel("Predicted", fontsize=14)
plt.title("Linear Regression", fontsize=18)
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2_score", r2_score(y_test,pred_RFR))
print("R2_score on training Data:", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score 0.8549888596225359
# R2_score on training Data: 96.78679155529886
# Mean Absolute Error: 1.3957404166410872
# Mean Squared Error: 6.347290096530987
# Root Mean Squared Error: 2.5193828800980187

# %%
knn=KNN()
knn.fit(x_train, y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2_score", r2_score(y_test,pred_knn))
print("R2_score on training Data:", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:", mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score 0.8445457272951029
# R2_score on training Data: 83.61874235057329
# Mean Absolute Error: 1.67158068279299
# Mean Squared Error: 6.804396979672083
# Root Mean Squared Error: 2.608523908204041

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train, y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2_score", r2_score(y_test,pred_GBR))
print("R2_score on training Data:", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2_score 0.8765465960826974
# R2_score on training Data: 87.33791362206902
# Mean Absolute Error: 1.2966860817523593
# Mean Squared Error: 5.403685303264547
# Root Mean Squared Error: 2.3245828234899584

# %%
lasso=Lasso()
lasso.fit(x_train, y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2_score", r2_score(y_test,pred_lasso))
print("R2_score on training Data:", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:", mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score 0.7301072518833369
# R2_score on training Data: 69.56117515260462
# Mean Absolute Error: 2.555715246751502
# Mean Squared Error: 11.81348938286576
# Root Mean Squared Error: 3.43707570223086

# %%
rd=Ridge()
rd.fit(x_train, y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("R2_score", r2_score(y_test,pred_rd))
print("R2_score on training Data:", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:", mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score 0.8058894457422248
# R2_score on training Data: 76.74021837444526
# Mean Absolute Error: 1.9557441129209303
# Mean Squared Error: 8.496423071120079
# Root Mean Squared Error: 2.9148624446309777

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train, y_train)
pred_DTR=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print("R2_score", r2_score(y_test,pred_DTR))
print("R2_score on training Data:", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_test,pred_DTR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_DTR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_DTR)))
# Out:
# R2_score 0.7414590409709323
# R2_score on training Data: 99.73368350085121
# Mean Absolute Error: 1.5027315369008214
# Mean Squared Error: 11.316609637861008
# Root Mean Squared Error: 3.364016890246095

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train, y_train)
pred_SVR=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2_score", r2_score(y_test,pred_SVR))
print("R2_score on training Data:", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_test,pred_SVR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_SVR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_SVR)))
# Out:
# R2_score 0.865077452277726
# R2_score on training Data: 79.78113839975973
# Mean Absolute Error: 1.009470896776619
# Mean Squared Error: 5.9057017876497575
# Root Mean Squared Error: 2.430164971282764

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train, y_train)
pred_ETR=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("R2_score", r2_score(y_test,pred_SVR))
print("R2_score on training Data:", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_test,pred_ETR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_ETR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# R2_score 0.865077452277726
# R2_score on training Data: 99.73368350085121
# Mean Absolute Error: 1.472477372137029
# Mean Squared Error: 7.994679088018178
# Root Mean Squared Error: 2.8274863550542872

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("difference between R2 score and cross validation score is-", (r2_score(y_test,pred_LR) - score.mean())*100)
# Out:
# [0.80610264 0.70333609 0.83436131 0.77339583 0.76333225]
# 0.7761056243879787
# difference between R2 score and cross validation score is- 6.844010290712421

# %%
score1=cross_val_score(RFR,x,y)
print(score1)
print(score1.mean())
print("difference between R2 score and cross validation score is-", (r2_score(y_test,pred_RFR) - score1.mean())*100)
# Out:
# [0.8385424  0.72102478 0.84894841 0.81679528 0.81159984]
# 0.8073821444804722
# difference between R2 score and cross validation score is- 4.760671514206372

# %%
score2=cross_val_score(knn,x,y)
print(score2)
print(score2.mean())
print("difference between R2 score and cross validation score is-", (r2_score(y_test,pred_knn) - score2.mean())*100)
# Out:
# [0.83492784 0.71983638 0.84617479 0.80314194 0.80191772]
# 0.8011997332823645
# difference between R2 score and cross validation score is- 4.334599401273842

# %%
score3=cross_val_score(GBR,x,y)
print(score3)
print(score3.mean())
print("difference between R2 score and cross validation score is-", (r2_score(y_test,pred_GBR) - score3.mean())*100)
# Out:
# [0.8636369  0.74629901 0.89797213 0.83267427 0.82666767]
# 0.8334499984093805
# difference between R2 score and cross validation score is- 4.309659767331686

# %%
score4=cross_val_score(lasso,x,y)
print(score4)
print(score4.mean())
print("difference between R2 score and cross validation score is-", (r2_score(y_test,pred_lasso) - score4.mean())*100)
# Out:
# [0.73515879 0.66561747 0.72621948 0.7069297  0.70659085]
# 0.7081032562963963
# difference between R2 score and cross validation score is- 2.200399558694066

# %%
score5=cross_val_score(rd,x,y)
print(score5)
print(score5.mean())
print("difference between R2 score and cross validation score is-", (r2_score(y_test,pred_rd) - score5.mean())*100)
# Out:
# [0.80607012 0.70348167 0.8342237  0.77343907 0.76333785]
# 0.7761104802074865
# difference between R2 score and cross validation score is- 2.9778965534738244

# %%
score6=cross_val_score(dtr,x,y)
print(score6)
print(score6.mean())
print("difference between R2 score and cross validation score is-", (r2_score(y_test,pred_DTR) - score6.mean())*100)
# Out:
# [0.72918568 0.62325751 0.61148489 0.67918993 0.59449554]
# 0.6475227102724149
# difference between R2 score and cross validation score is- 9.393633069851736

# %%
score7=cross_val_score(svr,x,y)
print(score7)
print(score7.mean())
print("difference between R2 score and cross validation score is-", (r2_score(y_test,pred_SVR) - score7.mean())*100)
# Out:
# [0.87015946 0.72132644 0.88172153 0.80357518 0.79729223]
# 0.8148149691625729
# difference between R2 score and cross validation score is- 5.026248311515314

# %%
score8=cross_val_score(etr,x,y)
print(score8)
print(score8.mean())
print("difference between R2 score and cross validation score is-", (r2_score(y_test,pred_ETR) - score8.mean())*100)
# Out:
# [0.81177453 0.67967565 0.84016518 0.78740997 0.79860296]
# 0.7835256574546839
# difference between R2 score and cross validation score is- 3.3826706487372626

# %% [markdown]
# On the basis of cross validation score and difference between R2 and Cross Score -GradientBoosting Regressor is the best model to fit the Data

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={"criterion":["friedman_mse"],"learning_rate":[0.01,0.1,1,10,100],"max_depth": [1,3,5,7,9],"n_estimators":[5,50,250,500]}

# %%
gscv=GridSearchCV(GradientBoostingRegressor(), param, cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse'],
#                          'learning_rate': [0.01, 0.1, 1, 10, 100],
#                          'max_depth': [1, 3, 5, 7, 9],
#                          'n_estimators': [5, 50, 250, 500]})

# %%
gscv.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.1,
#  'max_depth': 3,
#  'n_estimators': 50}

# %%
Model=GradientBoostingRegressor(criterion="friedman_mse",learning_rate=0.1,max_depth=3, n_estimators=50)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2_score", r2_score(y_test,pred))
print("Mean Absolute Error:", mean_absolute_error(y_test,pred))
print("Mean Squared Error:", mean_squared_error(y_test,pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score 0.8794347469358421
# Mean Absolute Error: 1.3066245370199094
# Mean Squared Error: 5.277267903472122
# Root Mean Squared Error: 2.2972304854916326

# %%
import pickle
filename="medicalcost.insurance"
pickle.dump(Model, open(filename, "wb"))

# %%
import pickle
loaded_model=pickle.load(open("medicalcost.insurance","rb"))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 87.9434746935842

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#                  0          1          2          3          4          5    \
# Predicted  14.227326  23.268356  15.863878  18.382538  13.681022  23.229081
# Original   12.867844  22.786048  13.906684  17.618522  12.920125  27.461222
#
#                  6          7          8          9    ...        392  \
# Predicted  24.150970  13.665895  33.774561  32.702609  ...  28.008946
# Original   23.968766  11.779716  38.060707  32.895165  ...  27.625175
#
#                  393        394        395        396        397        398  \
# Predicted  19.597330  17.837421  18.896953  23.084610  34.244704  18.111615
# Original   19.606616  16.468715  30.138583  22.493875  34.746259  28.187410
#
#                  399        400        401
# Predicted  34.538380  15.532225  26.576003
# Original   38.835395  14.165985  26.499353
#
# [2 rows x 402 columns]

# %% [markdown]
# On the basis of cross validation score and difference between R2 and Cross Score -GradientBoosting Regressor is the best model to fit the Data
# R2 score of test model is 87.94347
